# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('/content/sales data.xlsx')
df
# Out:
#           country  order_value_EUR       cost                 date  \
# 0          Sweden         98320.37   77722.25            8/23/2020
# 1          France         46296.26   40319.41            5/15/2020
# 2        Portugal        140337.34  115708.14  2020-04-09 00:00:00
# 3          France        203604.46  175344.16            6/26/2019
# 4              UK         63979.04   56032.84           10/22/2019
# ...           ...              ...        ...                  ...
# 996        France         69126.50    55902.6  2019-08-12 00:00:00
# 997        France        140943.88  120633.87            5/28/2020
# 998        France        124784.67  106853.11            5/22/2020
# 999       Germany         61968.26   50690.04           12/27/2020
# 1000  Netherlands        172453.10  145688.38            6/24/2020
#
#          category                     customer_name    sales_manager  \
# 0           Games                    Konopelski LLC     Maxie Marrow
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          1001 non-null   object
#  1   order_value_EUR  996 non-null    float64
#  2   cost             1001 non-null   object
#  3   date             1001 non-null   object
#  4   category         1001 non-null   object
#  5   customer_name    1001 non-null   object
#  6   sales_manager    1001 non-null   object
#  7   sales_rep        1001 non-null   object
#  8   device_type      996 non-null    object
#  9   order_id         1001 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 78.3+ KB

# %%
df.fillna({'order_value_EUR':000},inplace=True)
df.fillna({'device_type':'other'},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          1001 non-null   object
#  1   order_value_EUR  1001 non-null   float64
#  2   cost             1001 non-null   object
#  3   date             1001 non-null   object
#  4   category         1001 non-null   object
#  5   customer_name    1001 non-null   object
#  6   sales_manager    1001 non-null   object
#  7   sales_rep        1001 non-null   object
#  8   device_type      1001 non-null   object
#  9   order_id         1001 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 78.3+ KB

# %%
df.describe()
# Out:
#        order_value_EUR
# count      1001.000000
# mean     112628.516164
# std       61962.178115
# min           0.000000
# 25%       65014.840000
# 50%      104743.220000
# 75%      150313.190000
# max      383996.760000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['order_value_EUR'].plot(kind='hist', bins=20, title='order_value_EUR')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['order_value_EUR'].plot(kind='line', figsize=(8, 4), title='order_value_EUR')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.drop_duplicates()
# Out:
#           country  order_value_EUR       cost                 date  \
# 0          Sweden         98320.37   77722.25            8/23/2020
# 1          France         46296.26   40319.41            5/15/2020
# 2        Portugal        140337.34  115708.14  2020-04-09 00:00:00
# 3          France        203604.46  175344.16            6/26/2019
# 4              UK         63979.04   56032.84           10/22/2019
# ...           ...              ...        ...                  ...
# 996        France         69126.50    55902.6  2019-08-12 00:00:00
# 997        France        140943.88  120633.87            5/28/2020
# 998        France        124784.67  106853.11            5/22/2020
# 999       Germany         61968.26   50690.04           12/27/2020
# 1000  Netherlands        172453.10  145688.38            6/24/2020
#
#          category                     customer_name    sales_manager  \
# 0           Games                    Konopelski LLC     Maxie Marrow
# ...

# %%
df.drop(['date'],axis=1,inplace=True)

# %%
df.head(10)
# Out:
#     country  order_value_EUR       cost     category       customer_name  \
# 0    Sweden         98320.37   77722.25        Games      Konopelski LLC
# 1    France         46296.26   40319.41        Games          Wisoky Inc
# 2  Portugal        140337.34  115708.14   Appliances       Hegmann Group
# 3    France        203604.46  175344.16  Electronics     Kirlin and Sons
# 4        UK         63979.04   56032.84        Games      Schoen-Keeling
# 5     Italy        127075.41  110924.13     Clothing    Labadie and Sons
# 6    Sweden         69681.43   55529.13     Clothing  Romaguera-Dietrich
# 7    France         96795.99   81395.75   Appliances       Connelly-Mohr
# 8  Portugal        144725.34  115056.65  Smartphones          Wisoky Inc
# 9   Germany         32695.37   26375.35  Accessories      Johns and Sons
#
#      sales_manager            sales_rep device_type    order_id
# 0     Maxie Marrow   Tarrah Castelletti      Tablet  70-0511466
# ...

# %%
df=pd.DataFrame({
    'device_type':['Tablet','Tablet','PC','Mobile','PC','PC','PC','PC','PC','Mobile'],
    'cost':[98320.37,46296.26,140337.34,203604.46,63979.04,127075.41,69681.43,96765.99,144725.34,32695.37]
})
plt.bar(df['device_type'],df['cost'])
plt.xlabel("device Type")
plt.ylabel("Cost")
plt.title("Cost per device(sample set)")
plt.show()

# %%
print(df.dtypes)
# Out:
# country             object
# order_value_EUR    float64
# cost                object
# category            object
# customer_name       object
# sales_manager       object
# sales_rep           object
# device_type         object
# order_id            object
# dtype: object

# %%
df['cost']=pd.to_numeric(df['cost'],errors='coerce')

# %%
plt.plot(df['cost'],df['order_value_EUR'])
plt.xlabel("COST")
plt.ylabel("ORDER VALUE")
plt.title("ORDER VALUE AND COST")
plt.show()

# %%
df['country']=le.fit_transform(df['country'])
df['country']
# Out:
# 0       13
# 1        5
# 2       11
# 3        5
# 4       14
#         ..
# 996      5
# 997      5
# 998      5
# 999      6
# 1000    10
# Name: country, Length: 1001, dtype: int64

# %%
df['customer_name']=le.fit_transform(df['customer_name'])
df['customer_name']
# Out:
# 0       34
# 1       70
# 2       24
# 3       33
# 4       55
#         ..
# 996     11
# 997      2
# 998     65
# 999     51
# 1000    33
# Name: customer_name, Length: 1001, dtype: int64

# %%
df['category']=le.fit_transform(df['category'])
df['category']
# Out:
# 0       6
# 1       6
# 2       1
# 3       5
# 4       6
#        ..
# 996     5
# 997     1
# 998     5
# 999     5
# 1000    8
# Name: category, Length: 1001, dtype: int64

# %%
df['device_type']=le.fit_transform(df['device_type'])
df['device_type']
# Out:
# 0       2
# 1       2
# 2       1
# 3       0
# 4       1
#        ..
# 996     1
# 997     2
# 998     2
# 999     1
# 1000    1
# Name: device_type, Length: 1001, dtype: int64

# %%
df['sales_manager']=le.fit_transform(df['sales_manager'])
df['sales_manager']
# Out:
# 0        9
# 1       12
# 2        0
# 3       12
# 4        7
#         ..
# 996     12
# 997     12
# 998     12
# 999     14
# 1000     2
# Name: sales_manager, Length: 1001, dtype: int64

# %%
df['sales_rep']=le.fit_transform(df['sales_rep'])
df['sales_rep']
# Out:
# 0       32
# 1        1
# 2       15
# 3       16
# 4       17
#         ..
# 996      4
# 997      4
# 998     27
# 999     12
# 1000    26
# Name: sales_rep, Length: 1001, dtype: int64

# %%
df['customer_name']=le.fit_transform(df['customer_name'])
df['customer_name']
# Out:
# 0       34
# 1       70
# 2       24
# 3       33
# 4       55
#         ..
# 996     11
# 997      2
# 998     65
# 999     51
# 1000    33
# Name: customer_name, Length: 1001, dtype: int64

# %%
df['order_id']=le.fit_transform(df['order_id'])
df['order_id']
# Out:
# 0       681
# 1       764
# 2       643
# 3       266
# 4       246
#        ...
# 996      61
# 997     761
# 998     413
# 999     207
# 1000    592
# Name: order_id, Length: 1001, dtype: int64

# %%
x=df.drop(['cost'],axis=1)
x
# Out:
#       country  order_value_EUR  category  customer_name  sales_manager  \
# 0          13         98320.37         6             34              9
# 1           5         46296.26         6             70             12
# 2          11        140337.34         1             24              0
# 3           5        203604.46         5             33             12
# 4          14         63979.04         6             55              7
# ...       ...              ...       ...            ...            ...
# 996         5         69126.50         5             11             12
# 997         5        140943.88         1              2             12
# 998         5        124784.67         5             65             12
# 999         6         61968.26         5             51             14
# 1000       10        172453.10         8             33              2
#
#       sales_rep  device_type  order_id
# 0            32            2       681
# ...

# %%
y=df['cost']
y
# Out:
# 0        77722.25
# 1        40319.41
# 2       115708.14
# 3       175344.16
# 4        56032.84
#           ...
# 996      55902.60
# 997     120633.87
# 998     106853.11
# 999      50690.04
# 1000    145688.38
# Name: cost, Length: 1001, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#      country  order_value_EUR  category  customer_name  sales_manager  \
# 535        5         48890.14         4             30             12
# 696        5        274242.36         8             26             12
# 557       13        114427.36         7             66              9
# 643       11        105340.85         3             11              0
# 597       11        172989.17         2             51              0
# ..       ...              ...       ...            ...            ...
# 106        7        135662.46         2              8              4
# 270        5        106730.16         2             11             12
# 860        5        141948.11         3             63             12
# 435       13         37081.31         2             45              9
# 102        7         65831.42         5              5              4
#
#      sales_rep  device_type  order_id
# 535         27            1       853
# 696          1            0       797
# ...

# %%
x_test
# Out:
#      country  order_value_EUR  category  customer_name  sales_manager  \
# 521       12         81412.10         5             30              3
# 941       13         35354.22         9             10              9
# 741        6         48922.42         8             47             14
# 980        3        248261.86         9             17             10
# 411       11        211872.69         6             30              0
# ..       ...              ...       ...            ...            ...
# 332       11        159216.47         6             30              0
# 208       14        137306.45         3             16              7
# 992        5         87404.00         5             30             12
# 78         4         33190.03         5             28              5
# 29        14        122627.20         4             71              7
#
#      sales_rep  device_type  order_id
# 521          7            1       657
# 941         10            1       566
# ...

# %%
y_train
# Out:
# 535     41180.16
# 696    227950.25
# 557     93727.45
# 643     87285.43
# 597    142975.55
#          ...
# 106    116764.68
# 270     89503.91
# 860    112948.11
# 435     31304.04
# 102     52487.39
# Name: cost, Length: 800, dtype: float64

# %%
y_test
# Out:
# 521     64747.04
# 941     30517.76
# 741     39387.44
# 980    206727.65
# 411    177930.69
#          ...
# 332    137419.74
# 208    108732.98
# 992     69363.81
# 78      28397.39
# 29     100284.52
# Name: cost, Length: 201, dtype: float64

# %%
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=model.predict(x_test)
x_pred=model.predict(x_train)

# %%
y_pred
# Out:
# array([ 65326.8 ,  29424.59,  40174.38, 208757.67, 177637.49,  35669.83,
#         84030.23, 179100.09,  88395.39, 199607.15,  86770.57,  70319.99,
#         60336.7 ,  49239.69,  93727.45,  65326.8 ,  48076.46,  63987.04,
#        248275.93,  31708.77,  96750.22,  74089.48,  32368.3 , 123653.67,
#         62245.01,  83584.01,  73767.15,  47354.92,  36252.34,  32368.3 ,
#         77722.25,  48693.55, 122258.74,  22043.95, 135044.88,  98959.48,
#         34773.98, 141080.04,  69171.01, 133991.78, 120822.85,  63537.82,
#        103024.52, 100977.16,  48693.55,  39116.87,  65819.64,  47443.43,
#        154975.33, 201468.96, 100977.16,  94822.54,  89720.95, 244926.18,
#         56032.84,  76899.3 , 108600.06,  98171.79, 107920.06,  72309.95,
#        148852.74,  61604.51,  73264.23, 109310.55,  86665.  ,  31967.36,
#         43039.53, 122258.74,  45081.27, 107776.58,  83584.01,  92797.25,
#        199607.15, 213104.91,  24610.15, 139986.9 , 120822.85, 114132.43,
# ...

# %%
x_pred
# Out:
# array([ 41180.16, 227950.25,  93727.45,  87285.43, 142975.55,  75337.65,
#        114790.05,  32508.07,  31900.28, 146702.99,  29339.96,  43597.77,
#        104692.08,  40739.77,  29424.59,  65423.49,  80593.65,  73050.69,
#         43039.53, 116046.22,  62870.73,  44812.86,  23198.53, 138237.92,
#        115708.14,  35480.85,  41835.95, 118927.8 , 147370.42,  25662.45,
#         75504.84,  24408.08,  91430.07,  47688.55, 149866.33,  43918.78,
#         38880.67,  49916.42,  26800.66, 175344.16,  75669.26, 187446.59,
#         26593.2 , 130096.08,  88151.47, 213413.56,  40999.94, 288368.4 ,
#         64098.31, 114388.65, 135965.83, 212058.58,  56883.62, 116886.15,
#        130624.94,  89853.52,  49324.23, 221591.86, 110924.13,  32591.06,
#         63545.63, 106036.97,  66568.74,  17148.18, 117658.4 ,  91364.06,
#         51414.78,  14102.75, 108047.95,  74584.3 , 131067.85,  63359.4 ,
#        119178.53,  63982.11,  26375.35,  29698.03,  16364.25, 150324.5 ,
# ...

# %%
country=input("enter the country code:")
ordervalue=input("enter the order value:")
category=input("enter the category:")
customername=input("enter the customercode:")
salesmanager=input("enter salesmanager code:")
salesrep=input("enter sales rep code:")
devicetype=input("enter device type:")
orderid=input("enter order id:")

abc=[country,ordervalue,category,customername,salesmanager,salesrep,devicetype,orderid]
input1=abc
input1_as_numpy_array=np.asarray(input1)
input1_reshaped=input1_as_numpy_array.reshape(1,-1)
prediction=model.predict(input1_reshaped)
print("Prediction:",prediction)
# Out:
# enter the country code:12
# enter the order value:34565
# enter the category:5
# enter the customercode:17
# enter salesmanager code:12
# enter sales rep code:18
# enter device type:0
# enter order id:340
# Prediction: [28017.42]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
